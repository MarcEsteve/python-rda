# %% [markdown]
# # Automatización Búsqueda Web

# %%
import bs4
import requests
import lxml
import json

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'} 
res = requests.get('https://www.oscaro.es/filtro-de-aceite-7-g', headers=headers)
soup = bs4.BeautifulSoup(res.text, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="es-es">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Filtro de aceite al mejor precio - Oscaro</title>
# <!-- ____  _____ _________    ____  ____
#         / __ \/ ___// ____/   |  / __ \/ __ \
#        / / / /\__ \/ /   / /| | / /_/ / / / /
#       / /_/ /___/ / /___/ ___ |/ _, _/ /_/ /
#       \____//____/\____/_/  |_/_/ |_|\____/
#     -->
# <meta content="index, follow" name="robots"/>
# <meta content="Oscaro entrega en 48 h recambios de automÃ³vil de origen con descuento" name="Abstract"/>
# <meta content="Â¡Pide tus recambios de automÃ³vil por Internet!" name="Subject"/>
# <meta content="Filtro de aceite de coche al mejor precio, piezas nuevas y de origen : las mejores marcas - EnvÃ­o en punto de entrega o a domicilio - Oscaro" name="description"/>
# <meta content="es-es" name="Language"/>
# <meta content="website" property="og:type"/>
# <meta content="Filtro de aceite al mejor precio - Oscaro" property="og:title"/>
# <meta content="Filtro de aceite de coche al mejor precio, piezas nuevas y de origen : las mejores marcas - EnvÃ­o en punto de entrega o a domicilio - Oscaro" property="og:description"/>
# <meta content="https://oscaro.media/mu/layout/logo/logo-opengraph.png" property="og:image"/>
# <meta content="https://www.oscaro.es/filtro-de-aceite-7-g" property="og:url"/>
# <meta content="Oscaro" property="og:site_name"/>
# <meta content="Filtro de aceite al mejor precio - Oscaro" name="twitter:title"/>
# <meta content="Filtro de aceite de coche al mejor precio, piezas nuevas y de origen : las mejores marcas - EnvÃ­o en punto de entrega o a domicilio - Oscaro" name="twitter:description"/>
# <meta content="https://oscaro.media/mu/layout/logo/logo-opengraph.png" name="twitter:image"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Oscaro logo" name="twitter:image:alt"/>
# <meta content="app-id=1589069545D" name="apple-itunes-app"/>
# <link href="https://www.oscaro.com/filtre-a-huile-7-g" hreflang="fr-FR" rel="alternate"/><link href="https://www.oscaro.es/filtro-de-aceite-7-g" hreflang="es-ES" rel="alternate"/><link href="https://www.oscaro.be/fr/filtre-a-huile" hreflang="fr-BE" rel="alternate"/><link href="https://www.oscaro.pt/pt/filtro-de-oleo" hreflang="pt-PT" rel="alternate"/><link href="https://www.oscaro.de/olfilter-7-g" hreflang="de-DE" rel="alternate"/>
# <link href="https://www.oscaro.es/filtro-de-aceite-7-g" rel="canonical"/>
# <link href="https://www.oscaro.es/filtro-de-aceite-7-g?page=2" rel="next"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <link href="https://oscaro.media/yd/5.9.1/css/yoda.css" rel="stylesheet"/>
# <link as="font" crossorigin="anonymous" href="https://oscaro.media/mu/fonts/opensans/OpenSans-Regular.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://oscaro.media/mu/fonts/opensans/OpenSans-Bold.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://oscaro.media/mu/fonts/opensans/OpenSans-Italic.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://oscaro.media/mu/fonts/opensans/OpenSans-SemiBold.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://oscaro.media/mu/fonts/opensans/OpenSans-ExtraBold.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://oscaro.media/mu/fonts/opensans/OpenSans-ExtraBold-Italic.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://oscaro.media/yd/5.9.1/fonts/icoscaro.woff2" rel="preload" type="font/woff2"/><link as="image" href="https://oscaro.media/yd/5.9.1/img/common/sprite/dist/svg/sprite-common.svg" rel="preload" type="image/svg+xml"/><link as="image" href="https://oscaro.media/yd/5.9.1/img/common/sprite/dist/jpg/sprite-category.jpg" rel="preload" type="image/jpeg"/>
# <link href="https://oscaro.media/mu/layout/favicon/blue/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://oscaro.media/mu/layout/favicon/blue/icoscaro76.png" rel="icon" type="image/png"/>
# <link href="https://oscaro.media/mu/layout/favicon/blue/icoscaro76.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/>
# <link href="https://oscaro.media/mu/layout/favicon/blue/icoscaro120.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/>
# <link href="https://oscaro.media/mu/layout/favicon/blue/icoscaro152.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/>
# <script>
#       window.dataLayer = window.dataLayer || [];
#     </script>
# <script type="application/ld+json">{"@context":"https://schema.org","@type":"FAQPage","mainEntity":[{"@type":"Question","name":"Â¿CuÃ¡l es el papel de tu filtro de aceite?","acceptedAnswer":{"@type":"Answer","text":"El filtro de aceite es una parte muy importante de la vida de su motor y no debe ser descuidado. Garantiza la pureza del aceite del motor y reduce la fricciÃ³n. Filtra las partÃ­culas metÃ¡licas, el polvo y los residuos del proceso de combustiÃ³n. Si se acumulan impurezas en el aceite del motor, Ã©ste se atascarÃ¡. Los daÃ±os causados pueden ser irreversibles. El cartucho filtrante se coloca directamente en el motor o dentro de una carcasa de filtro. Para activar la compatibilidad con el lector de pantalla, pulse Ctrl+Alt+Z Para los atajos de teclado, pulse Ctrl+barra"}},{"@type":"Question","name":"Â¿CÃ³mo se cambia el filtro de aceite?","acceptedAnswer":{"@type":"Answer","text":"El filtro de aceite es una parte muy importante de la vida de su motor, por lo que no debe ser descuidado. Garantiza la pureza del aceite del motor y reduce la fricciÃ³n. Filtra las partÃ­culas metÃ¡licas, el polvo y los residuos de la combustiÃ³n. Si se acumulan impurezas en el aceite del motor, Ã©ste se atasca. Los daÃ±os causados pueden ser irreversibles. Se trata de un cartucho filtrante que se coloca directamente en el motor o en una carcasa diseÃ±ada para ello."}},{"@type":"Question","name":"Â¿Por quÃ© cambiar el filtro de aceite?","acceptedAnswer":{"@type":"Answer","text":"Al evitar que las partÃ­culas o los residuos de la combustiÃ³n lleguen al aceite de su motor, el filtro de aceite garantiza un rendimiento Ã³ptimo y duradero de su motor. Es importante cambiarlo porque puede obstruirse o daÃ±ar la lubricaciÃ³n. El aceite que ya no se filtra provoca un desgaste prematuro de su motor, hasta 30 veces mÃ¡s rÃ¡pido que el desgaste normal."}}]}</script>
# </head>
# <body class="country-es nojs" id="body">
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TB4F5JH" style="display:none;visibility:hidden" width="0"></iframe>
# <script type="application/javascript">
#       document.body.classList.remove("nojs");
#       document.body.classList.add((!(('ontouchstart' in window) || window.DocumentTouch && document instanceof DocumentTouch) && "no-") + "touchevents");
#         if (/[\?&]vident=[^&]+/.test(location.hash)) {
#         document.body.classList.add("loading-products");
#       }
#
#     </script>
# <div id="root"><div class="opcom-html" style="color:#ffffff;background-color:#F95E4C"><span class="hidden-xs">Â¡ENTREGA GRATIS DESDE 109â¬ EN LA WEB Y 69â¬ EN LA APP!</span><span class="show-xs">Â¡ENTREGA GRATIS DESDE 109â¬ EN LA WEB Y 69â¬ EN LA APP!</span></div><header class="header-container"><span hidden=""></span><nav class="header-static-nav"><span class="burger-toggle"><span></span><span></span><span></span></span><a class="logo" href="https://www.oscaro.es" name="Oscaro"><img alt="Oscaro es lÃ­der en repuestos nuevos y originales al mejor precio" height="48px" src="https://oscaro.media/mu/layout/logo/OSCARO_New_UI_White.svg" width="90px"/></a><ul class="header-static-nav-links"><li class="seek"><span class="ico-search show-xs"></span><div class="popin-fullpage-wrapper hidden-xs"><form autocomplete="off" class="form-search-ico" name="search-engine"><div class="form-item search"><div class="input"><input class="data-hj-allow" id="search-input-header" name="q" placeholder="Ej.: BaterÃ­a, GDB1330, â¦" type="text" value="Filtro de aceite"/><button class="ico-search" type="submit" value="ok"></button></div></div></form></div></li><li class="help"><a class="header-link ico-faq" href="/es/faq" name="help-link"><span class="header-link_label">Ayuda y contacto</span></a></li><li class="account"><a aria-label="Ver el formulario de acceso a la cuenta" class="header-link ico-user" data-account="off" href="/es/account/home" name="logged-off" rel="nofollow"><span class="header-link_label">Mi cuenta</span></a></li><li class="basket"><a class="header-link ico-cart" data-count="0" href="/es/cart" name="cart-link" rel="nofollow"><span class="header-link_label">Mi cesta</span><span aria-label="0 articles dans le panier" class="badge badge-count">0</span></a></li></ul></nav><div class="dropdown-header"><div class="bg-white show-xs"><h2 class="h3-size">Recambios de coche</h2><span class="ico-cross"></span></div><div class="dropdown-header-container pretty-scroll"><ul class="products-nav"><li class="dropdown-header-item product-nav-item" style="--counter-categories:20"><span class="dropdown-header-item-link ico-chevron-down right-ico">Recambios de coche</span></li><li class="product-nav-item"><a href="https://www.oscaro.es/aceite-de-motor-1862-g"><span>Aceite de motor</span></a></li><li class="dropdown-header-item product-nav-item" id="0"><span class="dropdown-header-item-link ico-chevron-down right-ico">Ruedas</span><div class="cat small"><span class="ico-cross"></span><ul class="categories"><li><a class="link" href="https://www.oscaro.es/neumaticos-4400-g"><span>NeumÃ¡ticos</span></a></li><li><a class="link" href="https://www.oscaro.es/cadenas-10745-gu"><span>Cadenas para nieve</span></a></li><li><a class="link" href="https://www.oscaro.es/tapacubos-ruedas-1436-gu"><span>Tapacubos de rueda</span></a></li><li><a class="link" href="https://www.oscaro.es/equipamiento-para-ruedas-702700-c"><span>Equipamientos y herramientas</span></a></li></ul></div></li><li class="dropdown-header-item product-nav-item" id="1"><span class="dropdown-header-item-link ico-chevron-down right-ico">Accesorios y limpieza</span><div class="cat small"><span class="ico-cross"></span><ul class="categories"><li><a class="link" href="https://www.oscaro.es/enganche-y-transporte-702675-c"><span>Barras de techo y transporte</span></a></li><li><a class="link" href="https://www.oscaro.es/accesorios-y-equipos-702666-c"><span>Accesorios y equipamiento</span></a></li><li><a class="link" href="https://www.oscaro.es/mantenimiento-y-limpieza-702667-c"><span>Mantenimiento y limpieza</span></a></li></ul></div></li><li class="product-nav-item"><a href="https://www.oscaro.es/herramientas-702627-c"><span>Herramientas</span></a></li></ul><ul class="header-external"><li><a class="ico-car-repare" href="/partnership/opisto" target="_blank">Piezas de ocasiÃ³n</a></li></ul></div></div></header><main class="main-container"><div class="flex-container"><div class="toast-banner toast-banner-na ...
# <script id="genartMatchesVehicle" type="application/transit+json">["~#'",null]</script><script id="topGenarts" type="application/transit+json">["~#list",[["^ ","~:score",102965,"~:genart-fitment-type","semi-technical","~:id","1862","~:labels",["^ ","~:label",["^ ","~:es","Aceite de motor"]]],["^ ","^1",36853,"^2","technical","^3","9","^4",["^ ","^5",["^ ","^6","Filtro combustible"]]],["^ ","^1",31713,"^2","technical","^3","8","^4",["^ ","^5",["^ ","^6","Filtro de aire (de coche)"]]],["^ ","^1",19403,"^2","technical","^3","424","^4",["^ ","^5",["^ ","^6","Filtro, aire habitÃ¡culo"]]],["^ ","^1",4003,"^2","technical","^3","593","^4",["^ ","^5",["^ ","^6","TapÃ³n del cambio de aceite"]]],["^ ","^1",3111,"^2","technical","^3","135","^4",["^ ","^5",["^ ","^6","Anillo de junta, tapÃ³n roscado de vaciado de aceite"]]],["^ ","^1",2184,"^2","universal","^3","10107","^4",["^ ","^5",["^ ","^6","Kit para el cambio de aceite"]]],["^ ","^1",1638,"^2","technical","^3","4055","^4",["^ ","^5",["^ ","^6","Juego de filtro"]]],["^ ","^1",1479,"^2","technical","^3","600","^4",["^ ","^5",["^ ","^6","Caja, filtro de combustible"]]]]]</script><script id="toasts" type="application/transit+json">["^ ","~:content",[],"~:variant",null,"~:timeout-ms",null,"~:qa-tag-label",null]</script><script id="slideInPanelsState" type="application/transit+json">["^ ","~:constraints",true,"~:codes-promo",false,"~:search-equivalents",false,"~:onboarding-seo",true]</script><script id="autocompleteData" type="application/transit+json">["^ ","~:results",null,"~:query","Filtro de aceite"]</script><script id="macroBoutique" type="application/transit+json">["~#'",null]</script><script id="cartState" type="application/transit+json">["~#'",null]</script><script id="marketingParams" type="application/transit+json">["^ ","~:seo-content",["^ ","~:es",[["^ ","~:content-type","~:faq","~:content",[["^ ","~:styled-description",[["~:p",["^ "],"El filtro de aceite es una parte muy importante de la vida de su motor y no debe ser descuidado. Garantiza la pureza del aceite del motor y reduce la fricciÃ³n. Filtra las partÃ­culas metÃ¡licas, el polvo y los residuos del proceso de combustiÃ³n. Si se acumulan impurezas en el aceite del motor, Ã©ste se atascarÃ¡. Los daÃ±os causados pueden ser irreversibles. El cartucho filtrante se coloca directamente en el motor o dentro de una carcasa de filtro. Para activar la compatibilidad con el lector de pantalla, pulse Ctrl+Alt+Z Para los atajos de teclado, pulse Ctrl+barra"]],"~:description","El filtro de aceite es una parte muy importante de la vida de su motor y no debe ser descuidado. Garantiza la pureza del aceite del motor y reduce la fricciÃ³n. Filtra las partÃ­culas metÃ¡licas, el polvo y los residuos del proceso de combustiÃ³n. Si se acumulan impurezas en el aceite del motor, Ã©ste se atascarÃ¡. Los daÃ±os causados pueden ser irreversibles. El cartucho filtrante se coloca directamente en el motor o dentro de una carcasa de filtro. Para activar la compatibilidad con el lector de pantalla, pulse Ctrl+Alt+Z Para los atajos de teclado, pulse Ctrl+barra","~:title","Â¿CuÃ¡l es el papel de tu filtro de aceite?"],["^ ","^5",[["~:p",["^ "],"El filtro de aceite es una parte muy importante de la vida de su motor, por lo que no debe ser descuidado. Garantiza la pureza del aceite del motor y reduce la fricciÃ³n. Filtra las partÃ­culas metÃ¡licas, el polvo y los residuos de la combustiÃ³n. Si se acumulan impurezas en el aceite del motor, Ã©ste se atasca. Los daÃ±os causados pueden ser irreversibles. Se trata de un cartucho filtrante que se coloca directamente en el motor o en una carcasa diseÃ±ada para ello."]],"^6","El filtro de aceite es una parte muy importante de la vida de su motor, por lo que no debe ser descuidado. Garantiza la pureza del aceite del motor y reduce la fricciÃ³n. Filtra las partÃ­culas metÃ¡licas, el polvo y los residuos de la combustiÃ³n. Si se acumulan impurezas en el aceite del motor, Ã©ste se atasca. Los daÃ±os causados pueden ser  ...
# <img alt="" id="navigationProductsData" src="..." style="display:none;"/><img alt="" id="productsData" src="data:image/png;base64,..." style="display:none;"/><img alt="" id="vehicleSearchData" src="..." style="display:none;"/><img alt="" id="seoData" src="data:image/png;base64,..." style="display:none;"/>
# <script src="https://cdnjs.cloudflare.com/polyfill/v3/polyfill.js?version=3.111.0&amp;features=default%2CElement.prototype.classList%2CMap%2CSet%2CrequestAnimationFrame%2CPromise%2CElement.prototype.closest%2CURLSearchParams" type="application/javascript"></script>
# <script src="https://oscaro.media/yd/5.9.1/js/main.js" type="text/javascript"></script>
# <script type="application/javascript">yoda.core.init()</script>
# <img alt="Yoda pixel" class="hidden" height="1" src="https://wte.oscaro.es/img/yoda.gif?utm_campaign=loading-ping-yoda&amp;utm_content=g" width="1"/>
# </body>
# </html>

# %%
soup.select('#root > main > div.flex-container > div.container.home-products > div.best-product > article:nth-child(1) > a > p > span')
elem1 = soup.select('#root > main > div.flex-container > div.container.home-products > div.best-product > article:nth-child(1) > a > p > span')
elem1[0].getText().strip()
# Out:
# '6,20 â\x82¬'

# %%
precio_1 = elem1[0].getText().strip().replace(' â\x82¬', '').replace(',', '.')

# %%
precio_1
# Out:
# '6.20'

# %%
elem2 = soup.select('#root > main > div.flex-container > div.container.home-products > div.best-product > article:nth-child(2) > a > p > span')
elem3 = soup.select('#root > main > div.flex-container > div.container.home-products > div.best-product > article:nth-child(3) > a > p > span')
precio_2 = elem2[0].getText().strip().replace(' â\x82¬', '').replace(',', '.')
precio_3 = elem3[0].getText().strip().replace(' â\x82¬', '').replace(',', '.')

# %%
precio_2, precio_3
# Out:
# ('14.70', '9.51')

# %% [markdown]
# ### Importamos la librería numpy para trabajar con arrays y valores numéricos

# %%
import numpy as np
array_precios = np.array([float(precio_1), float(precio_2), float(precio_3)])
precio_promedio = np.mean(array_precios)
precio_promedio
# Out:
# 10.136666666666665
